# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
#
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "/Users/chrissy/Documents/CG_Data_Science/Data-Science-Assignments/course_material/week_04/homework/Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
purchase_data_df = pd.DataFrame(purchase_data)
unique_SNs = purchase_data_df["SN"].unique()
unique_SNs_df = pd.DataFrame(unique_SNs)
unique_SNs_df.value_counts()
# Out:
# Zontibe81        1
# Zhisrisu83       1
# Frichynde86      1
# Frichossala54    1
# Frichosiala98    1
#                 ..
# Marokian45       1
# Marjask87        1
# Marirrasta50     1
# Marim28          1
# Adairialis76     1
# Length: 576, dtype: int64

# %% [markdown]
# There are 576 total players listed in purchase_data.

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# find number of unique items
unique_items = purchase_data_df["Item Name"].unique()
unique_items_df = pd.DataFrame(unique_items)
unique_items_df.value_counts()
# Out:
# Yearning Mageblade                 1
# Dreamsong                          1
# Fusion Pummel                      1
# Fury                               1
# Frenzy, Defender of the Harvest    1
#                                   ..
# Rusty Skull                        1
# Ritual Mace                        1
# Righteous Might                    1
# Riddle, Tribute of Ended Dreams    1
# Abyssal Shard                      1
# Length: 179, dtype: int64

# %%
# find average price
avg_price = purchase_data_df["Price"].mean()
avg_price_formatted = "${:,.2f}".format(avg_price)
avg_price_formatted
# Out:
# '$3.05'

# %%
# find number of purchases
purchase_data_df["Purchase ID"].value_counts()
# Out:
# 779    1
# 243    1
# 265    1
# 264    1
# 263    1
#       ..
# 517    1
# 516    1
# 515    1
# 514    1
# 0      1
# Name: Purchase ID, Length: 780, dtype: int64

# %%
# find total revenue
total_rev = purchase_data_df["Price"].sum()
total_rev_formatted = "${:,.2f}".format(total_rev)
total_rev_formatted
# Out:
# '$2,379.77'

# %%
# build summary dataframe
purchase_analysis = {"Number of Unique Items":179, "Avg Price":avg_price_formatted, 
                    "Number of Purchases":780, "Total Revenue":total_rev_formatted}
purchase_analysis_df = pd.DataFrame(purchase_analysis, index=[0],
                                   columns=["Number of Unique Items", "Avg Price",
                                           "Number of Purchases", "Total Revenue"])
print(purchase_analysis_df)
# Out:
#    Number of Unique Items Avg Price  Number of Purchases Total Revenue
# 0                     179     $3.05                  780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# remove duplicates by screen name, find player counts by gender
no_dupes = purchase_data_df.drop_duplicates(subset="SN")
no_dupes["Gender"].value_counts()
# Out:
# Male                     484
# Female                    81
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
# find player percentages by gender
gender_percent = (purchase_data_df["Gender"].value_counts())/780*100
gender_percent_df = pd.DataFrame(gender_percent)
gender_percent_df.rename(columns = {"Gender": "Gender %"}, inplace = True)
gender_percent_df
# Out:
#                         Gender %
# Male                   83.589744
# Female                 14.487179
# Other / Non-Disclosed   1.923077

# %%
# format percentages
format_dict = {'Gender %': '{:,.2f}%'}
gender_percent_df.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_a8b9d428_9be0_11eb_a851_b8e856471934" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Gender %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a8b9d428_9be0_11eb_a851_b8e856471934level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_a8b9d428_9be0_11eb_a851_b8e856471934row0_col0" class="data row0 col0" >83.59%</td>
#             </tr>
#             <tr>
#                         <th id="T_a8b9d428_9be0_11eb_a851_b8e856471934level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_a8b9d428_9be0_11eb_a851_b8e856471934row1_col0" class="data row1 col0" >14.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_a8b9d428_9be0_11eb_a851_b8e856471934level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
# ...

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#group data by Gender
purchase_data_bygender_df = purchase_data_df.groupby("Gender")
purchase_data_bygender_df.describe()
# Out:
#                       Purchase ID                                        \
#                             count        mean         std   min     25%
# Gender
# Female                      113.0  379.380531  211.605484  15.0  199.00
# Male                        652.0  392.516871  227.516414   0.0  193.75
# Other / Non-Disclosed        15.0  334.600000  234.524991   9.0  169.50
#
#                                                Age             ... Item ID  \
#                          50%     75%    max  count       mean  ...     75%
# Gender                                                         ...
# Female                 392.0  558.00  775.0  113.0  21.345133  ...   129.0
# Male                   390.5  592.25  779.0  652.0  22.917178  ...   141.0
# Other / Non-Disclosed  291.0  516.50  747.0   15.0  24.200000  ...   141.0
#
#                               Price                                          \
# ...

# %%
#find total spending by gender
purchase_data_bygender_df["Price"].sum()
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
#find average spending by gender
average_total_female = 361.94/81
average_total_female
# Out:
# 4.468395061728395

# %%
average_total_male = 1967.64/484
average_total_male
# Out:
# 4.065371900826446

# %%
average_total_other = 50.19/11
average_total_other
# Out:
# 4.5627272727272725

# %%
#assemble and display summary dataframe
bygender_summary = {"Purchase Count": [113, 652, 15], 
                    "Avg Purchase Price": ["$3.20", "$3.02", "$3.35"], 
                    "Total Purchase Value": ["$361.94", "1967.64", "$50.19"], 
                    "Avg Total Per Person": ["$4.46", "$4.07", "$4.56"]}
bygender_summary_df = pd.DataFrame(bygender_summary, index=["Male", "Female", "Other"], 
                    columns=["Purchase Count", "Avg Purchase Price", "Total Purchase Value",
                        "Avg Total Per Person"])
bygender_summary_df
# Out:
#         Purchase Count Avg Purchase Price Total Purchase Value  \
# Male               113              $3.20              $361.94
# Female             652              $3.02              1967.64
# Other               15              $3.35               $50.19
#
#        Avg Total Per Person
# Male                  $4.46
# Female                $4.07
# Other                 $4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#decide on binning benchmarks - what is max age listed in table?
purchase_data_df["Age"].max()
# Out:
# 45

# %%
#establish bin ends and labels, apply to data
age_bins = [0, 15, 30, 45]
age_labels = ["child", "young adult", "adult"]
pd.cut(purchase_data_df["Age"], age_bins, labels = age_labels)
# Out:
# 0      young adult
# 1            adult
# 2      young adult
# 3      young adult
# 4      young adult
#           ...
# 775    young adult
# 776    young adult
# 777    young adult
# 778          child
# 779    young adult
# Name: Age, Length: 780, dtype: category
# Categories (3, object): ['child' < 'young adult' < 'adult']

# %%
#create data frame including age group bins
purchases_agegroup_df = pd.DataFrame(purchase_data_df)
purchases_agegroup_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price    Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53  young adult
# 1                            Frenzied Scimitar   1.56        adult
# 2                                 Final Critic   4.88  young adult
# ...

# %%
#find total purchases by age group
purchases_agegroup_df["Age Group"].value_counts()
# Out:
# young adult    602
# adult           92
# child           86
# Name: Age Group, dtype: int64

# %%
#total spending
purchases_agegroup_df["Price"].sum()
# Out:
# 2379.77

# %%
#drop dupes

age_bins = [0, 15, 30, 45]
age_labels = ["child", "young adult", "adult"]
pd.cut(no_dupes_df["Age"], age_bins, labels = age_labels)
# Out:
# 0      young adult
# 1            adult
# 2      young adult
# 3      young adult
# 4      young adult
#           ...
# 773    young adult
# 774          child
# 775    young adult
# 777    young adult
# 778          child
# Name: Age, Length: 576, dtype: category
# Categories (3, object): ['child' < 'young adult' < 'adult']

# %%
#create dataframe with no dupes info
no_dupes_df["Age Group"] = pd.cut(no_dupes_df["Age"], age_bins, labels = age_labels)
no_dupes_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 774          774     Jiskjask80   11    Male      101
# 775          775     Aethedru70   21  Female       60
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
#
#                                      Item Name  Price    Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53  young adult
# 1                            Frenzied Scimitar   1.56        adult
# 2                                 Final Critic   4.88  young adult
# ...

# %%
#apply groupby to no dupes, describe to find average prices
purchase_data_byagedemo_df = no_dupes_df.groupby("Age Group")
purchase_data_byagedemo_df.describe()
# Out:
#             Purchase ID                                                       \
#                   count        mean         std   min     25%    50%     75%
# Age Group
# child              65.0  387.600000  229.575137  26.0  165.00  411.0  546.00
# young adult       441.0  346.231293  218.345725   0.0  162.00  329.0  524.00
# adult              70.0  341.557143  239.048090   1.0  142.25  307.5  516.75
#
#                       Age             ... Item ID         Price            \
#                max  count       mean  ...     75%    max  count      mean
# Age Group                             ...
# child        778.0   65.0  11.907692  ...  145.00  183.0   65.0  3.117077
# young adult  777.0  441.0  22.231293  ...  141.00  183.0  441.0  3.056440
# adult        761.0   70.0  36.014286  ...  139.25  179.0   70.0  3.116429
#
#
#                   std   min   25%   50%     75%   max
# Age Group
# child        1.091529  1.09  2.05  3.14  4.1900  4.94
# ...

# %%
#find number of unique players per age group

no_dupes_df["Age Group"].value_counts()
# Out:
# young adult    441
# adult           70
# child           65
# Name: Age Group, dtype: int64

# %%
#find percentages by age group

agedemo_percent = (no_dupes_df["Age Group"].value_counts())/576*100
agedemo_percent_df = pd.DataFrame(agedemo_percent)
agedemo_percent_df.rename(columns = {"Age Group": "Age Group %"}, inplace = True)
agedemo_percent_df
# Out:
#              Age Group %
# young adult    76.562500
# adult          12.152778
# child          11.284722

# %%
# format percentages
format_dict = {'Age Group %': '{:,.2f}%'}
agedemo_percent_df.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_e781f12c_9c5d_11eb_a851_b8e856471934" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age Group %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e781f12c_9c5d_11eb_a851_b8e856471934level0_row0" class="row_heading level0 row0" >young adult</th>
#                         <td id="T_e781f12c_9c5d_11eb_a851_b8e856471934row0_col0" class="data row0 col0" >76.56%</td>
#             </tr>
#             <tr>
#                         <th id="T_e781f12c_9c5d_11eb_a851_b8e856471934level0_row1" class="row_heading level0 row1" >adult</th>
#                         <td id="T_e781f12c_9c5d_11eb_a851_b8e856471934row1_col0" class="data row1 col0" >12.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_e781f12c_9c5d_11eb_a851_b8e856471934level0_row2" class="row_heading level0 row2" >child</th>
# ...

# %%
#summary - age demographic table

agedemo_summary = {"Age Group Count": [65, 441, 70], 
                    "Age Group %": ["11.28", "76.56%", "12.15%"]}
agedemo_summary_df = pd.DataFrame(agedemo_summary, index=["Child", "Young Adult", "Adult"], 
                    columns=["Age Group Count", "Age Group %"])
agedemo_summary_df
# Out:
#              Age Group Count Age Group %
# Child                     65       11.28
# Young Adult              441      76.56%
# Adult                     70      12.15%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#redisplay original data by age group for reference

purchases_agegroup_df = pd.DataFrame(purchase_data_df)
purchases_agegroup_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price    Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53  young adult
# 1                            Frenzied Scimitar   1.56        adult
# 2                                 Final Critic   4.88  young adult
# ...

# %%
#re-display no dupes data by age group for reference

purchase_data_byagedemo_df = no_dupes_df.groupby("Age Group")
purchase_data_byagedemo_df.describe()
# Out:
#             Purchase ID                                                       \
#                   count        mean         std   min     25%    50%     75%
# Age Group
# child              65.0  387.600000  229.575137  26.0  165.00  411.0  546.00
# young adult       441.0  346.231293  218.345725   0.0  162.00  329.0  524.00
# adult              70.0  341.557143  239.048090   1.0  142.25  307.5  516.75
#
#                       Age             ... Item ID         Price            \
#                max  count       mean  ...     75%    max  count      mean
# Age Group                             ...
# child        778.0   65.0  11.907692  ...  145.00  183.0   65.0  3.117077
# young adult  777.0  441.0  22.231293  ...  141.00  183.0  441.0  3.056440
# adult        761.0   70.0  36.014286  ...  139.25  179.0   70.0  3.116429
#
#
#                   std   min   25%   50%     75%   max
# Age Group
# child        1.091529  1.09  2.05  3.14  4.1900  4.94
# ...

# %%
#total spending by age group

purchase_data_byagedemo_df["Price"].sum()
# Out:
# Age Group
# child           202.61
# young adult    1347.89
# adult           218.15
# Name: Price, dtype: float64

# %%
#find average totals by age group - (total spending * %)/# in age group

average_total_child = (2379.77*.1128)/65
average_total_child
# Out:
# 4.129816246153847

# %%
average_total_young_adult = (2379.77*.7656)/441
average_total_young_adult
# Out:
# 4.1314102312925165

# %%
average_total_adult = (2379.77*.1215)/70
average_total_adult
# Out:
# 4.130600785714285

# %%
#pull together data in dataframe, display

byage_summary = {"Purchase Count": [86, 602, 92], 
                    "Avg Purchase Price": ["$3.09", "$3.03", "$3.15"], 
                    "Total Purchase Value": ["$265.56", "1824.62", "$289.59"], 
                    "Avg Total Per Person": ["$4.13", "$4.13", "$4.13"]}
byage_summary_df = pd.DataFrame(bygender_summary, index=["Male", "Female", "Other"], 
                    columns=["Purchase Count", "Avg Purchase Price", "Total Purchase Value",
                        "Avg Total Per Person"])
byage_summary_df
# Out:
#         Purchase Count Avg Purchase Price Total Purchase Value  \
# Male               113              $3.20              $361.94
# Female             652              $3.02              1967.64
# Other               15              $3.35               $50.19
#
#        Avg Total Per Person
# Male                  $4.46
# Female                $4.07
# Other                 $4.56

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#determine top spenders by username

purchase_data_df["SN"].value_counts()
# Out:
# Lisosia93       5
# Iral74          4
# Idastidru52     4
# Haillyrgue51    3
# Asur53          3
#                ..
# Yarithrgue83    1
# Mindimnya67     1
# Haisurra41      1
# Heunadil74      1
# Sally64         1
# Name: SN, Length: 576, dtype: int64

# %%
#add up each top user's spending to find total, divide totals by # of purchases to find
#average spend per user

total_val_Lisosia93 = 2.52 + 3.19 + 4.64 + 3.81 + 4.8
total_val_Lisosia93
# Out:
# 18.96

# %%
avg_price_Lisosia93 = total_val_Lisosia93/5
avg_price_Lisosia93
# Out:
# 3.7920000000000003

# %%
total_val_Iral74 = 4.03 + 1.63 + 4.14 + 3.82
total_val_Iral74
# Out:
# 13.620000000000001

# %%
avg_price_Iral74 = total_val_Iral74/4
avg_price_Iral74
# Out:
# 3.4050000000000002

# %%
total_val_Idastidru52 = 4.93 + 4.03 + 1.6 + 4.89
total_val_Idastidru52
# Out:
# 15.45

# %%
avg_price_Idastidru52 = total_val_Idastidru52/4
avg_price_Idastidru52
# Out:
# 3.8625

# %%
total_val_Haillyrgue51 = 2.52 + 2.38 + 4.6
total_val_Haillyrgue51
# Out:
# 9.5

# %%
avg_price_Haillyrgue51 = total_val_Haillyrgue51/3
avg_price_Haillyrgue51
# Out:
# 3.1666666666666665

# %%
total_val_Asur53 = 2.42 + 1.44 + 3.58
total_val_Asur53
# Out:
# 7.4399999999999995

# %%
avg_price_Asur53 = total_val_Asur53/3
avg_price_Asur53
# Out:
# 2.48

# %%
#compile data in dataframe, display and sort

top_spenders_summary = {"Purchase Count": [5, 4, 4, 3, 3], 
                        "Avg Purchase Price": ["$3.79", "$3.40", "$3.86", "$3.17", "$2.48"],
                    "Total Purchase Value": ["$18.96", "$13.62", "$15.45", "$9.50", "$7.44"]}
top_spenders_summary_df = pd.DataFrame(top_spenders_summary, index=["Lisosia93", "Iral74",
                        "Idastidru52", "Haillyrgue51", "Asur53"], 
                    columns=["Purchase Count", "Avg Purchase Price", "Total Purchase Value"])
top_spenders_summary_df.sort_values("Total Purchase Value", ascending=False)

#I don't know why this isn't sorting correctly!  I tried it with both float (ex. 9.5)
# and currency (ex. $9.50) formatting - came out wonky both times
# Out:
#               Purchase Count Avg Purchase Price Total Purchase Value
# Haillyrgue51               3              $3.17                $9.50
# Asur53                     3              $2.48                $7.44
# Lisosia93                  5              $3.79               $18.96
# Idastidru52                4              $3.86               $15.45
# Iral74                     4              $3.40               $13.62

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#retrieve data from indicated columns

most_popular_df = purchase_data_df.loc[:, ["Item ID", "Item Name", "Price"]]
most_popular_df
# Out:
#      Item ID                                  Item Name  Price
# 0        108  Extraction, Quickblade Of Trembling Hands   3.53
# 1        143                          Frenzied Scimitar   1.56
# 2         92                               Final Critic   4.88
# 3        100                                Blindscythe   3.27
# 4        131                                       Fury   1.44
# ..       ...                                        ...    ...
# 775       60                                       Wolf   3.54
# 776      164                           Exiled Doomblade   1.63
# 777       67      Celeste, Incarnation of the Corrupted   3.46
# 778      101                               Final Critic   4.19
# 779       50                                       Dawn   4.60
#
# [780 rows x 3 columns]

# %%
#drop duplicates to get actual item count

most_popular_nodupes = most_popular_df.drop_duplicates()
most_popular_nodupes
# Out:
#      Item ID                                  Item Name  Price
# 0        108  Extraction, Quickblade Of Trembling Hands   3.53
# 1        143                          Frenzied Scimitar   1.56
# 2         92                               Final Critic   4.88
# 3        100                                Blindscythe   3.27
# 4        131                                       Fury   1.44
# ..       ...                                        ...    ...
# 673      130                                      Alpha   2.07
# 700       90                                   Betrayer   2.94
# 717      177   Winterthorn, Defender of Shifting Worlds   2.08
# 727      104                         Gladiator's Glaive   1.93
# 751      180                                Stormcaller   3.36
#
# [183 rows x 3 columns]

# %%
#group by item name and price

grouped_most_popular_df = most_popular_df.groupby(["Item Name", "Price"])
grouped_most_popular_df.count()
# Out:
#                                        Item ID
# Item Name                       Price
# Abyssal Shard                   2.67         5
# Aetherius, Boon of the Blessed  3.39         5
# Agatha                          3.08         6
# Alpha                           2.07         3
# Alpha, Oath of Zeal             4.05         3
# ...                                        ...
# Wolf                            3.54         8
# Wolf, Promise of the Moonwalker 4.48         6
# Worldbreaker                    2.60         4
# Yearning Crusher                4.18         3
# Yearning Mageblade              3.82         5
#
# [183 rows x 1 columns]

# %%
most_pop_item = grouped_most_popular_df["Item Name"].count()
most_pop_item
# Out:
# Item Name                        Price
# Abyssal Shard                    2.67     5
# Aetherius, Boon of the Blessed   3.39     5
# Agatha                           3.08     6
# Alpha                            2.07     3
# Alpha, Oath of Zeal              4.05     3
#                                          ..
# Wolf                             3.54     8
# Wolf, Promise of the Moonwalker  4.48     6
# Worldbreaker                     2.60     4
# Yearning Crusher                 4.18     3
# Yearning Mageblade               3.82     5
# Name: Item Name, Length: 183, dtype: int64

# %%
#merge popular items date into one dataframe

inner_merge_df = pd.merge(most_popular_nodupes, most_pop_item, on="Price")
inner_merge_df
# Out:
#      Item ID                                Item Name_x  Price  Item Name_y
# 0        108  Extraction, Quickblade Of Trembling Hands   3.53            9
# 1        143                          Frenzied Scimitar   1.56            6
# 2         92                               Final Critic   4.88            8
# 3        100                                Blindscythe   3.27            5
# 4        100                                Blindscythe   3.27            5
# ..       ...                                        ...    ...          ...
# 266      127               Heartseeker, Reaver of Souls   3.92            2
# 267      130                                      Alpha   2.07            3
# 268      177   Winterthorn, Defender of Shifting Worlds   2.08            2
# 269      104                         Gladiator's Glaive   1.93            1
# 270      180                                Stormcaller   3.36            1
#
# [271 rows x 4 columns]

# %%
#rename last column to Purchase Count

inner_merge_df.rename(columns = {'Item Name_y':'Purchase Count'}, inplace = True)
inner_merge_df
# Out:
#      Item ID                                Item Name_x  Price  Purchase Count
# 0        108  Extraction, Quickblade Of Trembling Hands   3.53               9
# 1        143                          Frenzied Scimitar   1.56               6
# 2         92                               Final Critic   4.88               8
# 3        100                                Blindscythe   3.27               5
# 4        100                                Blindscythe   3.27               5
# ..       ...                                        ...    ...             ...
# 266      127               Heartseeker, Reaver of Souls   3.92               2
# 267      130                                      Alpha   2.07               3
# 268      177   Winterthorn, Defender of Shifting Worlds   2.08               2
# 269      104                         Gladiator's Glaive   1.93               1
# 270      180                                Stormcaller   3.36               1
#
# [271 rows x 4 columns]

# %%
#calculate total purchase value per item

total_purchase_val = inner_merge_df["Price"] * inner_merge_df["Purchase Count"]
total_purchase_val
# Out:
# 0      31.77
# 1       9.36
# 2      39.04
# 3      16.35
# 4      16.35
#        ...
# 266     7.84
# 267     6.21
# 268     4.16
# 269     1.93
# 270     3.36
# Length: 271, dtype: float64

# %%
#summary data frame for Most Popular Items
inner_merge_df["Total Purchase Value"] = inner_merge_df["Price"] * inner_merge_df["Purchase Count"]
format_dict = {'Price': '${:,.2f}', "Total Purchase Value": "${:,.2f}"}
inner_merge_df.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_e5bc1540_9c5b_11eb_a851_b8e856471934" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Item ID</th>        <th class="col_heading level0 col1" >Item Name_x</th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Purchase Count</th>        <th class="col_heading level0 col4" >Total Purchase Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e5bc1540_9c5b_11eb_a851_b8e856471934level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e5bc1540_9c5b_11eb_a851_b8e856471934row0_col0" class="data row0 col0" >108</td>
#                         <td id="T_e5bc1540_9c5b_11eb_a851_b8e856471934row0_col1" class="data row0 col1" >Extraction, Quickblade Of Trembling Hands</td>
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# sort inner_merge_df by TPV in descending order and display

inner_merge_sortby_tpv = inner_merge_df.sort_values("Total Purchase Value", ascending=False)
format_dict = {'Price': '${:,.2f}', "Total Purchase Value": "${:,.2f}"}
inner_merge_sortby_tpv.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_f2280c08_9c5b_11eb_a851_b8e856471934" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Item ID</th>        <th class="col_heading level0 col1" >Item Name_x</th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Purchase Count</th>        <th class="col_heading level0 col4" >Total Purchase Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2280c08_9c5b_11eb_a851_b8e856471934level0_row0" class="row_heading level0 row0" >57</th>
#                         <td id="T_f2280c08_9c5b_11eb_a851_b8e856471934row0_col0" class="data row0 col0" >178</td>
#                         <td id="T_f2280c08_9c5b_11eb_a851_b8e856471934row0_col1" class="data row0 col1" >Oathbreaker, Last Hope of the Breaking Storm</td>
# ...
