# %% [markdown]
# 1) Create a study guide for all the supervised learning models we have gone over. Include information about how the algorithms work, how they are evaluated, and any other information you deem necessary. Use your own words. Do NOT copy mine or that of articles we have read.

# %% [markdown]
# 2) Do the same as question 1 except for unsupervised learning models. Something that is necessary for many models is determining number, so specify how you determine the number of clusters for example. Apply this concept to any other algorithms it is relevant for.

# %% [markdown]
# 3) Preprocess the customer data https://www.kaggle.com/carrie1/ecommerce-data . How are you handling nulls? What process(es) are you using to encode and normalize the data?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

#convert e-commerce data to pandas dataframe
#
df = pd.read_csv("ecommercedata.csv", encoding = "ISO-8859-1", engine='python')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#look at data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
#do we have null values?  if so, in which columns?
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#missing descriptions and customerIDs should not affect the data quality much
#still likely legit purchases - some buyers may not have an account (no customerID),
#description may be a recently added field - older products/transactions may not have been retrofitted with descriptions
#aka, would be more disruptive/hurt model accuracy to drop affected entries

#let's fill null customerIDs with zeroes
df['CustomerID'].fillna(0, inplace=True)
df.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID        0
# Country           0
# dtype: int64

# %%
#fill null Descriptions with... a description of their lack of descriptions (Descriptionception)
df['Description'].fillna('No description provided', inplace=True)
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
#make CustomerID whole numbers
df['CustomerID'] = df['CustomerID'].astype(int)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55       17850  United Kingdom
# 1  12/1/2010 8:26       3.39       17850  United Kingdom
# 2  12/1/2010 8:26       2.75       17850  United Kingdom
# 3  12/1/2010 8:26       3.39       17850  United Kingdom
# 4  12/1/2010 8:26       3.39       17850  United Kingdom

# %%
#what are the most expensive items?
sorted_df = df.sort_values('UnitPrice', ascending=False)
sorted_df.head(30)
# Out:
#        InvoiceNo  StockCode      Description  Quantity       InvoiceDate  \
# 222681   C556445          M           Manual        -1   6/10/2011 15:31
# 524602   C580605  AMAZONFEE       AMAZON FEE        -1   12/5/2011 11:36
# 43702    C540117  AMAZONFEE       AMAZON FEE        -1     1/5/2011 9:55
# 43703    C540118  AMAZONFEE       AMAZON FEE        -1     1/5/2011 9:57
# 15017     537632  AMAZONFEE       AMAZON FEE         1   12/7/2010 15:08
# 16356    C537651  AMAZONFEE       AMAZON FEE        -1   12/7/2010 15:49
# 15016    C537630  AMAZONFEE       AMAZON FEE        -1   12/7/2010 15:04
# 16232    C537644  AMAZONFEE       AMAZON FEE        -1   12/7/2010 15:34
# 524601   C580604  AMAZONFEE       AMAZON FEE        -1   12/5/2011 11:35
# 299982   A563185          B  Adjust bad debt         1   8/12/2011 14:50
# 446533   C574902  AMAZONFEE       AMAZON FEE        -1   11/7/2011 15:21
# 173277   C551685       POST          POSTAGE        -1    5/3/2011 12:51
# 173382    551697       POST          POSTAGE         1    5/3/2011 13:46
# 342635   C566899  AMAZONFEE       AMAZON FEE        -1   9/15/2011 13:53
# 191386   C553355  AMAZONFEE       AMAZON FEE        -1   5/16/2011 13:58
# 173391   C551699          M           Manual        -1    5/3/2011 14:12
# 422376    573080          M           Manual         1  10/27/2011 14:20
# 406406    571751          M           Manual         1  10/19/2011 11:18
# 374542    569382          M           Manual         1   10/3/2011 16:44
# 347948    567353          M           Manual         1   9/19/2011 16:14
# 119632    546558          M           Manual         1    3/15/2011 9:50
# 297438    562946          M           Manual         1    8/11/2011 9:38
# 144826    548813          M           Manual         1    4/4/2011 13:03
# 493020    578149        DOT   DOTCOM POSTAGE         1  11/23/2011 11:11
# 524892    580610        DOT   DOTCOM POSTAGE         1   12/5/2011 11:48
# 406407    571751          M           Manual         1  10/19/2011 11:18
# 525134    580612        DOT   DOTCOM POSTAGE         1   12/5/2011 11:58
# 144829    548820          M           Manual         1    4/4/2011 13:04
# 343000    566927          M           Manual         1   9/15/2011 15:20
# 502058    578833        DOT   DOTCOM POSTAGE         1  11/25/2011 15:23
#
#         UnitPrice  CustomerID         Country
# 15017    13541.33           0  United Kingdom
# 299982   11062.06           0  United Kingdom
# 173382    8142.75       16029  United Kingdom
# 297723    4505.17           0  United Kingdom
# 268028    4287.63           0  United Kingdom
# 422351    4161.06       12536          France
# 422376    4161.06       12536          France
# 406406    3949.32       12744       Singapore
# 374542    3155.95       15502  United Kingdom
# 347948    2653.95           0       Hong Kong
# 119632    2583.76           0       Hong Kong
# 297438    2500.00       15581  United Kingdom
# 144826    2382.92       12744       Singapore
# 493020    2275.54           0  United Kingdom
# 524892    2196.67           0  United Kingdom
# 406407    2118.74       12744       Singapore
# 525134    2114.00           0  United Kingdom
# 144829    2053.07       12744       Singapore
# 343000    2033.10       17846  United Kingdom
# 502058    2028.25           0  United Kingdom

# %%
#looks like we still have some random fees
#hard to say whether to keep "Manual" entries - may be valid sales, but do they do more to help the other data
#than hinder it?
#let's go ahead and try dropping them, along with remaining Amazon fees, postage fees, & dotcom fees
no_fees_df = no_negs_df.loc[(no_negs_df["StockCode"] != 'DOT') & (no_negs_df["StockCode"] != 'M') & 
                           (no_negs_df["StockCode"] != 'AMAZONFEE') & (no_negs_df["StockCode"] != 'POST')
                           & (no_negs_df["StockCode"] != 'B')]
no_fees_df = no_fees_df.sort_values('UnitPrice', ascending=False)
no_fees_df.head(15)
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 222682    556446     22502  PICNIC BASKET WICKER 60 PIECES         1
# 222680    556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 118769    546480     22656    VINTAGE BLUE KITCHEN CABINET         1
# 171178    551393     22656    VINTAGE BLUE KITCHEN CABINET         1
# 32484     539080     22655     VINTAGE RED KITCHEN CABINET         1
# 4989      536835     22655     VINTAGE RED KITCHEN CABINET         1
# 133994    547814     22656    VINTAGE BLUE KITCHEN CABINET         1
# 82768     543253     22655     VINTAGE RED KITCHEN CABINET         1
# 51636     540647     22655     VINTAGE RED KITCHEN CABINET         1
# 205759    554836     22655     VINTAGE RED KITCHEN CABINET         1
# 182648    552560     22826   LOVE SEAT ANTIQUE WHITE METAL         1
# 110843    545698     22826   LOVE SEAT ANTIQUE WHITE METAL         1
# 183128    552648     22826   LOVE SEAT ANTIQUE WHITE METAL         1
# 166111    550890     22826   LOVE SEAT ANTIQUE WHITE METAL         1
# 156737    550163     22826   LOVE SEAT ANTIQUE WHITE METAL         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
#
# 160542   4/18/2011 13:20       2.40       15749  United Kingdom
# 291247    8/4/2011 18:06       0.72       12931  United Kingdom
# 348316   9/20/2011 11:05       1.08       17450  United Kingdom
# 4850     12/2/2010 16:48       0.55       15299  United Kingdom
# 447035   11/7/2011 17:42       1.95           0  United Kingdom
# 347563   9/19/2011 13:39       0.85       12901  United Kingdom

# %%
#what countries are represented in this data?
no_fees_df.Country.value_counts()
# Out:
# United Kingdom          485234
# Germany                   8659
# France                    8102
# EIRE                      7889
# Spain                     2423
# Netherlands               2326
# Switzerland               1936
# Belgium                   1935
# Portugal                  1464
# Australia                 1184
# Norway                    1049
# Channel Islands            747
# Italy                      741
# Finland                    647
# Cyprus                     612
# Unspecified                446
# Sweden                     428
# Austria                    384
# Denmark                    367
# Poland                     325
# Japan                      321
# Israel                     295
# Hong Kong                  279
# Singapore                  215
# Iceland                    182
# USA                        179
# Canada                     150
# Greece                     142
# Malta                      109
# United Arab Emirates        67
# European Community          57
# RSA                         57
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              24
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
#what types of products are represented by data?
no_fees_df.Description.value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2327
# JUMBO BAG RED RETROSPOT               2115
# REGENCY CAKESTAND 3 TIER              2019
# PARTY BUNTING                         1707
# LUNCH BAG RED RETROSPOT               1594
#                                       ...
# wrongly sold (22719) barcode             1
# PINK POLKADOT KIDS BAG                   1
# WALL ART , THE MAGIC FOREST              1
# on cargo order                           1
# WATERING CAN SINGLE HOOK PISTACHIO       1
# Name: Description, Length: 4074, dtype: int64

# %%
#KMeans doesn't like the alpha characters in StockCode
#let's label encode it
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
no_fees_df['StockCode'] = label_encoder.fit_transform(no_fees_df['StockCode'])
no_fees_df.head(10)
# Out:
#        InvoiceNo  StockCode                     Description  Quantity  \
# 222682    556446       1387  PICNIC BASKET WICKER 60 PIECES         1
# 222680    556444       1387  PICNIC BASKET WICKER 60 PIECES        60
# 118769    546480       1534    VINTAGE BLUE KITCHEN CABINET         1
# 171178    551393       1534    VINTAGE BLUE KITCHEN CABINET         1
# 32484     539080       1533     VINTAGE RED KITCHEN CABINET         1
# 4989      536835       1533     VINTAGE RED KITCHEN CABINET         1
# 133994    547814       1534    VINTAGE BLUE KITCHEN CABINET         1
# 82768     543253       1533     VINTAGE RED KITCHEN CABINET         1
# 51636     540647       1533     VINTAGE RED KITCHEN CABINET         1
# 205759    554836       1533     VINTAGE RED KITCHEN CABINET         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 222682  6/10/2011 15:33      649.5       15098  United Kingdom
# 222680  6/10/2011 15:28      649.5       15098  United Kingdom
# 118769  3/14/2011 11:38      295.0       13452  United Kingdom
# 171178  4/28/2011 12:22      295.0       14973  United Kingdom
# 32484   12/16/2010 8:41      295.0       16607  United Kingdom
# 4989    12/2/2010 18:06      295.0       13145  United Kingdom
# 133994  3/25/2011 14:19      295.0       13452  United Kingdom
# 82768    2/4/2011 15:32      295.0       14842  United Kingdom
# 51636   1/10/2011 14:57      295.0       17406  United Kingdom
# 205759  5/26/2011 16:25      295.0       13015  United Kingdom

# %%
no_fees_df['InvoiceDate'] = pd.to_datetime(no_fees_df['InvoiceDate'])
no_fees_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-b8ca9a08b80a> in <module>
#       1 no_fees_df['InvoiceDate'] = pd.to_datetime(no_fees_df['InvoiceDate'])
# ----> 2 no_fees_df['InvoiceDate'] = (no_fees_df['InvoiceDate']).toordinal()
#       3 no_fees_df
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'toordinal'

# %%
ecomm_df = no_fees_df.drop('Description', axis=1)
ecomm_df.head()
# Out:
#        InvoiceNo  StockCode  Quantity InvoiceDate  UnitPrice  CustomerID  \
# 222682    556446       1387         1  2011-06-10      649.5       15098
# 222680    556444       1387        60  2011-06-10      649.5       15098
# 118769    546480       1534         1  2011-03-14      295.0       13452
# 171178    551393       1534         1  2011-04-28      295.0       14973
# 32484     539080       1533         1  2010-12-16      295.0       16607
#
#                Country
# 222682  United Kingdom
# 222680  United Kingdom
# 118769  United Kingdom
# 171178  United Kingdom
# 32484   United Kingdom

# %%
ecomm_df['InvoiceDate']=ecomm_df['InvoiceDate'].astype(str)
ecomm_df.head()
# Out:
#        InvoiceNo  StockCode  Quantity InvoiceDate  UnitPrice  CustomerID  \
# 222682    556446       1387         1  2011-06-10      649.5       15098
# 222680    556444       1387        60  2011-06-10      649.5       15098
# 118769    546480       1534         1  2011-03-14      295.0       13452
# 171178    551393       1534         1  2011-04-28      295.0       14973
# 32484     539080       1533         1  2010-12-16      295.0       16607
#
#                Country
# 222682  United Kingdom
# 222680  United Kingdom
# 118769  United Kingdom
# 171178  United Kingdom
# 32484   United Kingdom

# %%
from sklearn.preprocessing import StandardScaler
#Standardize
sc= StandardScaler()
scaled = sc.fit_transform(ecomm_df)
scaled.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-6a8f099c201e> in <module>
#       2 #Standardize
#       3 sc= StandardScaler()
# ----> 4 scaled = sc.fit_transform(ecomm_df)
#       5 scaled.head()
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# /Applications/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# /Applications/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '2011-06-10'

# %% [markdown]
# 4) Perform k-means on this dataset for customer segments. Customer segments help determine what types of people buy your product, which allows you to target more people like your usual customers. Should you look at all the data, or which subset of data should you use? What is the ideal number of clusters? Which approach did you use to find the ideal number of clusters and why?

# %%
x1 = no_fees_df['UnitPrice'].values
x2 = no_fees_df['Quantity'].values

# %%
#find the optimal number of clusters with elbow method  
from sklearn.cluster import KMeans

#initialize wcss list
wcss_list= []

for n in range(1, 11):  
    kmeans = KMeans(n_clusters = n, init = 'k-means++', random_state = 18)  
    kmeans.fit([x1, x2])  
    wcss_list.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss_list)  
plt.title('Elbow Method - Unit Price')  
plt.xlabel('Number of clusters(k)')  
plt.ylabel('wcss_list')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-37d579b430af> in <module>
#       7 for n in range(1, 11):
#       8     kmeans = KMeans(n_clusters = n, init = 'k-means++', random_state = 18)
# ----> 9     kmeans.fit([x1, x2])
#      10     wcss_list.append(kmeans.inertia_)
#      11
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     982                                 accept_large_sparse=False)
#     983
# --> 984         self._check_params(X)
#     985         random_state = check_random_state(self.random_state)
#     986         sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in _check_params(self, X)
#     810         # n_clusters
#     811         if X.shape[0] < self.n_clusters:
# --> 812             raise ValueError(f"n_samples={X.shape[0]} should be >= "
#     813                              f"n_clusters={self.n_clusters}.")
#     814
#
# ValueError: n_samples=2 should be >= n_clusters=3.

# %%
#find the optimal number of clusters with elbow method  
from sklearn.cluster import KMeans

#initialize wcss list
wcss_list= []

for n in range(1, 11):  
    kmeans = KMeans(n_clusters = n, init = 'k-means++', random_state = 18)  
    kmeans.fit(x2)  
    wcss_list.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss_list)  
plt.title('Elbow Method - Quantity')  
plt.xlabel('Number of clusters(k)')  
plt.ylabel('wcss_list')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-11e4ec7b0a96> in <module>
#       7 for n in range(1, 11):
#       8     kmeans = KMeans(n_clusters = n, init = 'k-means++', random_state = 18)
# ----> 9     kmeans.fit(x2)
#      10     wcss_list.append(kmeans.inertia_)
#      11
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# /Applications/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '6/10/2011 15:33'

# %% [markdown]
# 5) Perform hierarchical clustering for customer segments. What is the ideal number of clusters? Which approach did you use to find the ideal number of clusters and why?

# %% [markdown]
# 6) Compare the results of 4 and 5. Which approach do you think is best? Why?
